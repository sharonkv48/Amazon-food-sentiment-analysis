# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
import nltk

# %%
# Read in data
df = pd.read_csv(r"C:\Users\sharo\PROJECTS_AHHHH\sentiment analysis\Reviews.csv\Reviews.csv")
print(df.shape)
df = df.head(500)
print(df.shape)
# Out:
# (568454, 10)
# (500, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
ax = df['Score'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %%
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk

# Replace 'path_to_nltk_data' with the actual path to your NLTK data directory
nltk.data.path.append(r"C:\Users\sharo\AppData\Roaming\nltk_data\tokenizers\punkt")

# %%
pip install --upgrade nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (3.8.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: click in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (4.58.0)

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk

# Replace 'path_to_nltk_data' with the actual path to your NLTK data directory
nltk.data.path.append(r"C:\Users\sharo\AppData\Roaming\nltk_data\taggers\averaged_perceptron_tagger")

# %%
pip install --upgrade nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (4.58.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
import nltk
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\sharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
# Replace 'path_to_nltk_data' with the actual path to your NLTK data directory
nltk.data.path.append(r"C:\Users\sharo\AppData\Roaming\nltk_data\chunkers\maxent_ne_chunker")

# %%
pip install --upgrade nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nltk) (4.58.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\sharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
pip install --upgrade ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (8.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: comm>=0.1.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: backcall in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: typing-extensions in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.7.4.3)
# Requirement already satisfied: colorama in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.15.0)

# %%
pip install --upgrade jupyter
# Out:
# Requirement already satisfied: jupyter in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (1.0.0)
# Requirement already satisfied: notebook in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter) (7.0.2)
# Requirement already satisfied: qtconsole in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter) (5.4.3)
# Requirement already satisfied: jupyter-console in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter) (7.7.4)
# Requirement already satisfied: ipykernel in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter) (6.25.1)
# Requirement already satisfied: ipywidgets in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter) (8.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (8.12.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: packaging in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (23.1)
# Requirement already satisfied: psutil in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (6.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipywidgets->jupyter) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipywidgets->jupyter) (3.0.8)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-console->jupyter) (3.0.39)
# Requirement already satisfied: pygments in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-console->jupyter) (2.16.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (4.9.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (6.0.0)
# Requirement already satisfied: defusedxml in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (6.8.0)
# Requirement already satisfied: jinja2>=3.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: importlib-resources>=5.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from notebook->jupyter) (6.0.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from notebook->jupyter) (2.7.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from notebook->jupyter) (2.24.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from notebook->jupyter) (4.0.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from notebook->jupyter) (0.2.3)
# Requirement already satisfied: ipython-genutils in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from qtconsole->jupyter) (0.2.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from qtconsole->jupyter) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from importlib-metadata>=3.6->nbconvert->jupyter) (3.16.2)
# Requirement already satisfied: backcall in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: decorator in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.0)
# Requirement already satisfied: pickleshare in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: typing-extensions in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.7.4.3)
# Requirement already satisfied: colorama in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=6.1.12->ipykernel->jupyter)
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7.1)
# Requirement already satisfied: argon2-cffi in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.4.4)
# Requirement already satisfied: overrides in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: pywinpty in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.11)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.6.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.2.0)
# Requirement already satisfied: tomli in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.1)
# Requirement already satisfied: babel>=2.10 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.14)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.19.0)
# Requirement already satisfied: requests>=2.28 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Requirement already satisfied: fastjsonschema in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.18.0)
# Requirement already satisfied: wcwidth in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: exceptiongroup in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.1.3)
# Collecting typing-extensions (from ipython>=7.23.1->ipykernel->jupyter)
#   Obtaining dependency information for typing-extensions from https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.7.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: pytz>=2015.7 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2021.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2020.12.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.4)
# Requirement already satisfied: uri-template in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.2.3)
# Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Installing collected packages: typing-extensions, python-dateutil
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
# Successfully installed python-dateutil-2.8.2 typing-extensions-4.7.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.0.158 requires numpy>=1.22.2, but you have numpy 1.20.1 which is incompatible.
# ultralytics 8.0.158 requires tqdm>=4.64.0, but you have tqdm 4.58.0 which is incompatible.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\sharo\anaconda3\envs\myenv1\lib\site-packages (23.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
# Now we have sentiment score and metadata
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('Compund Score by Amazon Star Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Downloading (…)lve/main/config.json: 100%|██████████| 747/747 [00:00<?, ?B/s]
# c:\Users\sharo\anaconda3\envs\myenv1\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sharo\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)olve/main/vocab.json: 100%|██████████| 899k/899k [00:00<00:00, 960kB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 597kB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 150/150 [00:00<?, ?B/s]
# Downloading pytorch_model.bin: 100%|██████████| 499M/499M [01:40<00:00, 4.96MB/s]

# %%
# VADER results on example
print(example)
sia.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.97635514, 'roberta_neu': 0.02068747, 'roberta_pos': 0.0029573708}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')

# %%
results_df.columns
# Out:
# Index(['Id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
sns.pairplot(data=results_df,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()

# %%
results_df.query('Score == 1') \
    .sort_values('roberta_pos', ascending=False)['Text'].values[0]
# Out:
# 'I felt energized within five minutes, but it lasted for about 45 minutes. I paid $3.99 for this drink. I could have just drunk a cup of coffee and saved my money.'

# %%
results_df.query('Score == 1') \
    .sort_values('vader_pos', ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %%
results_df.query('Score == 5') \
    .sort_values('roberta_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
results_df.query('Score == 5') \
    .sort_values('vader_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)lve/main/config.json: 100%|██████████| 629/629 [00:00<?, ?B/s]
# Downloading model.safetensors: 100%|██████████| 268M/268M [01:02<00:00, 4.31MB/s]
# Downloading (…)okenizer_config.json: 100%|██████████| 48.0/48.0 [00:00<00:00, 5.94kB/s]
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 563kB/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
sent_pipeline('I am from future')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9436211585998535}]

# %%
sent_pipeline('i am going to make biriyni')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9879751801490784}]

# %%
sent_pipeline('hate u')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9994033575057983}]
